# %%
import pandas as pd

# %%
df_performance_sepsis=pd.read_csv("./results/Ours/sepsis/11-26-2025_17-39-58/performance_classifiers.csv", index_col=0)

# %%
df_performance_sepsis
# Out:
#    Precision    Recall  Classifier  f1-scores       Class
# 0   0.861111  0.794872         0.2   0.826667  SIRS-False
# 1   0.954023  0.970760         0.2   0.962319   SIRS-True

# %%
df_performance_rtfm=pd.read_csv("./results/Ours/rtfm/11-26-2025_17-52-19/performance_classifiers.csv",index_col=0)

# %%
df_performance_rtfm
# Out:
#    Precision    Recall  Classifier  f1-scores       Class
# 0   1.000000  1.000000         0.2   1.000000   collected
# 1   0.638978  0.970874         0.2   0.770713   dismissed
# 2   0.951554  0.995273         0.2   0.972923  fully_paid
# 3   0.986492  0.855912         0.2   0.916574  unresolved
